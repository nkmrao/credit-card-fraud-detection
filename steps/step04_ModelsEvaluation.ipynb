# %% [markdown]
# #### Load libraries

# %%
import pandas as pd

from scripts.modelling import LogisticRegressionModel, RandomForestModel, GradientBoostingModel

# %% [markdown]
# #### Load data

# %%
# Load the modelling data

data_path = '../data/modelling_data.csv'
df = pd.read_csv(data_path)

# %%
X = df.drop(columns=['fradulent_user_flag'])
y = df['fradulent_user_flag']

# %% [markdown]
# #### Logistic Regression Model Evaluation

# %%
model = LogisticRegressionModel(X, y)
model.evaluate()
# Out:
# Accuracy: 84.44%
# Precision: 76.27%
# Recall: 100.0%

# %%
model.feature_importance()

# %% [markdown]
# #### Random Forest Model Evaluation

# %%
model = RandomForestModel(X, y)
model.evaluate()
# Out:
# Accuracy: 86.67%
# Precision: 85.11%
# Recall: 88.89%

# %%
model.feature_importance()

# %% [markdown]
# #### Gradient Boosting Model

# %%
model = GradientBoostingModel(X, y)
model.evaluate()
# Out:
# Accuracy: 85.56%
# Precision: 84.78%
# Recall: 86.67%

# %%
model.feature_importance()
